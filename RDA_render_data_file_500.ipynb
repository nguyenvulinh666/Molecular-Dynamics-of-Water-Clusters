# %% [markdown]
# # 500K

# %%
import numpy as np

# %%
consevered_quantity_500_nvt = []
time_500_nvt = [0.001, 0.002, 0.0005, 0.0008]

# %%
for ts in time_500_nvt:
    consevered_quantity_500_nvt.append(np.loadtxt(f"/home/linh/Numerical method 2/Part 2/NumericalII2025/NumericalII2022/MDTutorial/Exercises/Exc1/final_exam-nvt-500/time{ts}/output.dat"))

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Set a modern style
plt.style.use('default')  # Use Seaborn's modern style for clean aesthetics "seaborn-v0_8"
# plt.rcParams['font.family'] = 'Helvetica'  # Modern sans-serif font
plt.rcParams['axes.linewidth'] = 1.2  # Slightly thicker axes for emphasis
plt.rcParams['xtick.labelsize'] = 12  # Consistent tick label size
plt.rcParams['ytick.labelsize'] = 12

# Define figure and axes with modern proportions
fig, ax = plt.subplots(2, 2, figsize=(6, 4), sharex=True, sharey=True, 
                       dpi=150)  # Adjusted size and higher DPI for clarity

# Define a modern color palette (if 'color' is not provided)
# Using 'viridis' colormap for a professional gradient
colors = sns.color_palette("rocket", n_colors=4)

# Plot data on each subplot
ax[0, 0].plot(consevered_quantity_500_nvt[0][:, 0], consevered_quantity_500_nvt[0][:, 1], 
              label=f"t={time_500_nvt[0]} ps", color=colors[0], linewidth=2)

ax[0, 1].plot(consevered_quantity_500_nvt[1][:, 0], consevered_quantity_500_nvt[1][:, 1], 
              label=f"t={time_500_nvt[1]} ps", color=colors[1], linewidth=2)

ax[1, 0].plot(consevered_quantity_500_nvt[2][:, 0], consevered_quantity_500_nvt[2][:, 1], 
              label=f"t={time_500_nvt[2]} ps", color=colors[2], linewidth=2)

ax[1, 1].plot(consevered_quantity_500_nvt[3][:, 0], consevered_quantity_500_nvt[3][:, 1], 
              label=f"t={time_500_nvt[3]} ps", color=colors[3], linewidth=2)


# Customize each subplot
for a in ax.flat:
    a.grid(True, linestyle='--', alpha=0.5)  # Subtle gridlines
    # a.legend(fontsize=12, loc='upper right')  # Legend in each subplot
    a.tick_params(axis='both', which='both', direction='in', length=5)  # Clean ticks

fig.legend(loc='upper center' ,bbox_to_anchor=(0.5, 1.06),  ncol=4, fancybox=True, shadow=True, fontsize=10)
# Set axis limits (based on commented-out code)
# ax[0, 0].set_xlim(0, 50)
# ax[0, 0].set_ylim(-158.4, -158)

# Add labels and title
fig.supxlabel("Time (ps)", fontsize=14, y=0.05)  # Shared x-label below
fig.supylabel("Conserved Quantity (T=500K)", fontsize=14, x=0.02, y=0.55)  # Shared y-label on left
# fig.suptitle("Conserved Quantity at T=300K", fontsize=16, y=1.1)  # Title above

# Adjust layout to prevent overlap
plt.tight_layout()

# Display the plot
# plt.show()
fig.savefig('./figures/Conserved_quality_500K.pdf', format='pdf', dpi=300, bbox_inches='tight')

# %%
int(len(consevered_quantity_500_nvt[0])/4)
# Out:
# 5000

# %%
# Drift energy
for i in range(len(consevered_quantity_500_nvt)):
    drift_energy = abs(consevered_quantity_500_nvt[i][:,1][int(len(consevered_quantity_500_nvt[i])/4)] - consevered_quantity_500_nvt[i][:,1][-1])
    print(f"Drift energy for t={time_500_nvt[i]} fs: {drift_energy}")
# Out:
# Drift energy for t=0.001 fs: 0.7313000000000045
# Drift energy for t=0.002 fs: 7.317300000000017
# Drift energy for t=0.0005 fs: 0.04680000000001883
# Drift energy for t=0.0008 fs: 0.2978999999999985

# %%
temp_data_500_nvt = []

# %%
for ts in time_500_nvt:
    temp_data_500_nvt.append(np.loadtxt(f"/home/linh/Numerical method 2/Part 2/NumericalII2025/NumericalII2022/MDTutorial/Exercises/Exc1/final_exam-nvt-500/time{ts}/engtemp.dat"))

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Set a modern style
plt.style.use('default')  # Use Seaborn's modern style for clean aesthetics "seaborn-v0_8"
# plt.rcParams['font.family'] = 'Helvetica'  # Modern sans-serif font
plt.rcParams['axes.linewidth'] = 1.2  # Slightly thicker axes for emphasis
plt.rcParams['xtick.labelsize'] = 12  # Consistent tick label size
plt.rcParams['ytick.labelsize'] = 12

# Define figure and axes with modern proportions
fig, ax = plt.subplots(2, 2, figsize=(6, 4), sharex=True, sharey=True, 
                       dpi=150)  # Adjusted size and higher DPI for clarity

# Define a modern color palette (if 'color' is not provided)
# Using 'viridis' colormap for a professional gradient
colors = sns.color_palette("rocket", n_colors=4)

# Plot data on each subplot
ax[0, 0].plot(temp_data_500_nvt[0][:, 0], temp_data_500_nvt[0][:, 1], 
              label=f"t={time_500_nvt[0]} ps", color=colors[0], linewidth=2)
ax[0, 1].plot(temp_data_500_nvt[1][:, 0], temp_data_500_nvt[1][:, 1], 
              label=f"t={time_500_nvt[1]} ps", color=colors[1], linewidth=2)
ax[1, 0].plot(temp_data_500_nvt[2][:, 0], temp_data_500_nvt[2][:, 1], 
              label=f"t={time_500_nvt[2]} ps", color=colors[2], linewidth=2)
ax[1, 1].plot(temp_data_500_nvt[3][:, 0], temp_data_500_nvt[3][:, 1], 
              label=f"t={time_500_nvt[3]} ps", color=colors[3], linewidth=2)

# Customize each subplot
for a in ax.flat:
    a.grid(True, linestyle='--', alpha=0.5)  # Subtle gridlines
    # a.legend(fontsize=12, loc='upper right')  # Legend in each subplot
    a.tick_params(axis='both', which='both', direction='in', length=5)  # Clean ticks

fig.legend(loc='upper center' ,bbox_to_anchor=(0.5, 1.06),  ncol=4, fancybox=True, shadow=True, fontsize=10)
# Set axis limits (based on commented-out code)
# ax[0, 0].set_xlim(0, 50)
# ax[0, 0].set_ylim(-158.4, -158)

# Add labels and title
fig.supxlabel("Time (ps)", fontsize=14, y=0.05)  # Shared x-label below
fig.supylabel("Temperature (T=500K)", fontsize=14, x=0.03, y=0.55)  # Shared y-label on left
# fig.suptitle("Temperature (K) at T=300K", fontsize=16, y=1.05)  # Title above

# Adjust layout to prevent overlap
plt.tight_layout()

# Display the plot
# plt.show()
fig.savefig('./figures/Temperature_500K.pdf', format='pdf', dpi=300, bbox_inches='tight')

# %%
pos_data_500_nvt = []

# %%
for ts in time_500_nvt:
    pos_data_500_nvt.append(np.loadtxt(f"/home/linh/Numerical method 2/Part 2/NumericalII2025/NumericalII2022/MDTutorial/Exercises/Exc1/final_exam-nvt-500/time{ts}/engcfg.dat"))

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Set a modern style
plt.style.use('default')  # Use Seaborn's modern style for clean aesthetics "seaborn-v0_8"
# plt.rcParams['font.family'] = 'Helvetica'  # Modern sans-serif font
plt.rcParams['axes.linewidth'] = 1.2  # Slightly thicker axes for emphasis
plt.rcParams['xtick.labelsize'] = 12  # Consistent tick label size
plt.rcParams['ytick.labelsize'] = 12

# Define figure and axes with modern proportions
fig, ax = plt.subplots(2, 2, figsize=(6, 4), sharex=True, sharey=True, 
                       dpi=150)  # Adjusted size and higher DPI for clarity

# Define a modern color palette (if 'color' is not provided)
# Using 'viridis' colormap for a professional gradient
colors = sns.color_palette("rocket", n_colors=4)

# Plot data on each subplot
ax[0, 0].plot(pos_data_500_nvt[0][:, 0], pos_data_500_nvt[0][:, 1], 
              label=f"t={time_500_nvt[0]} ps", color=colors[0], linewidth=2)
ax[0, 1].plot(pos_data_500_nvt[1][:, 0], pos_data_500_nvt[1][:, 1], 
              label=f"t={time_500_nvt[1]} ps", color=colors[1], linewidth=2)
ax[1, 0].plot(pos_data_500_nvt[2][:, 0], pos_data_500_nvt[2][:, 1], 
              label=f"t={time_500_nvt[2]} ps", color=colors[2], linewidth=2)
ax[1, 1].plot(pos_data_500_nvt[3][:, 0], pos_data_500_nvt[3][:, 1], 
              label=f"t={time_500_nvt[3]} ps", color=colors[3], linewidth=2)

# Customize each subplot
for a in ax.flat:
    a.grid(True, linestyle='--', alpha=0.5)  # Subtle gridlines
    # a.legend(fontsize=12, loc='upper right')  # Legend in each subplot
    a.tick_params(axis='both', which='both', direction='in', length=5)  # Clean ticks

fig.legend(loc='upper center' ,bbox_to_anchor=(0.5, 1.06),  ncol=4, fancybox=True, shadow=True, fontsize=10)
# Set axis limits (based on commented-out code)
# ax[0, 0].set_xlim(0, 50)
# ax[0, 0].set_ylim(-158.4, -158)

# Add labels and title
fig.supxlabel("Time (ps)", fontsize=14, y=0.05)  # Shared x-label below
fig.supylabel("Potential energy (kJ/mol) \n at T=500K", fontsize=14, x=0.08, horizontalalignment='center')  # Shared y-label on left
# fig.suptitle("Potential energy (kJ/mol) at T=300K", fontsize=16, y=1.05)  # Title above

# Adjust layout to prevent overlap
plt.tight_layout()

# Display the plot
# plt.show()
fig.savefig('./figures/PE_500K.pdf', format='pdf', dpi=300, bbox_inches='tight')

# %%
dataOW = np.loadtxt("/home/linh/Numerical method 2/Part 2/NumericalII2025/NumericalII2022/MDTutorial/Exercises/Exc1/final_exam-nvt-500/time0.0005/displacement-OW.txt")


distanceOW = 25.2
# dis_r = []
BigOW = [[dataOW[(j+1)*80: (j+2)*80][:, i:i+3] for i in range(0, 60,3)] for j in range(4)]

# %%
np.shape(BigOW)
# Out:
# (4, 20, 80, 3)

# %%
distanceOW = 25.2
dis_rOW = [[] for _ in range(4)]

for int in range(len(BigOW)):
    for j in range(20):
        for k in range(j+1, (20)):
            for i in range(np.shape(BigOW[int])[1]):
                x = np.abs(BigOW[int][j][i][0] - BigOW[int][k][i][0])
                x = np.mod(x, distanceOW)

                if abs(x-distanceOW) < x:
                    x = abs(x-distanceOW)

                y = np.abs(BigOW[int][j][i][1] - BigOW[int][k][i][1])
                y = np.mod(y, distanceOW)

                if abs(y-distanceOW) < y:
                    y = abs(y-distanceOW)

                z = np.abs(BigOW[int][j][i][2] - BigOW[int][k][i][2])
                z = np.mod(z, distanceOW)

                if abs(z-distanceOW) < z:
                    z = abs(z-distanceOW)
            
                r = np.sqrt(x**2+y**2+z**2)
                
                # if r <= rcut:
                dis_rOW[int].append(r)

# %%
counts_dataOW = []
for i in range(4):
    bins_edgeOW = np.linspace(0, 25.196959335562/2*np.sqrt(3), 300)
    countsOW, _ = np.histogram(dis_rOW[i], bins=bins_edgeOW)
    disbin = bins_edgeOW[1] - bins_edgeOW[0]

    countsOW = countsOW /4/np.pi/(bins_edgeOW[:-1]+disbin/2)**2/(disbin)


    # The total area equals to length of number of the data we have initially
    normalzieOW = len(dis_rOW[i])

    # print(normalizeOW)
    # plt.plot(bins_edge[1:], counts/normalzie)
    # print(bins_edge)
    counts_dataOW.append(countsOW/normalzieOW*25.196959335562**3)
    # counts_dataOW.append(countsOW)
    a = np.dot(counts_dataOW[i], bins_edgeOW[1:]**2)*4*np.pi*(bins_edgeOW[1] - bins_edgeOW[0]) / 25.196959335562**3
    print(a)
# Out:
# 1.0080063984442347
# 1.0078978597552104
# 1.0078773601951319
# 1.0078151261595722

# %%
ow_ow = np.loadtxt("/home/linh/Numerical method 2/Part 2/NumericalII2025/NumericalII2022/MDTutorial/Exercises/Exc1/final_exam-nvt-500/time0.0005/ow-ow.txt")

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Set a modern style
plt.style.use('seaborn-v0_8-whitegrid')  # Clean white background with subtle gridlines
# plt.rcParams['font.family'] = 'Helvetica'  # Professional sans-serif font
plt.rcParams['axes.labelsize'] = 14  # Font size for labels
plt.rcParams['xtick.labelsize'] = 12  # Font size for ticks
plt.rcParams['ytick.labelsize'] = 12
plt.rcParams['legend.fontsize'] = 12

# Create the figure and axes
fig, ax = plt.subplots(figsize=(6, 4), dpi=150)  # Modern size and resolution

# Define data (assumed to be provided)
x = bins_edgeOW[1:]  # x-values (e.g., bin centers or edges)
y = np.average(counts_dataOW, axis=0)  # Mean values
yerr = np.std(counts_dataOW, axis=0)  # Standard deviation for error bars

# Plot error bars with modern styling
ax.errorbar(x, y, yerr=yerr, label="Estimates", 
            marker='o', markersize=5, markerfacecolor='green', markeredgecolor='black', 
            markeredgewidth=0.8
            , color='black', ecolor='black', 
            capsize=2, capthick=2, linewidth=1., alpha=0.9)

ax.plot(ow_ow[:,0], ow_ow[:,1], label="RDFDAT-DATA", color="purple")

ax.set_xlim(2, 7)

# Customize the plot
ax.set_xlabel(r"r ($\AA$)", fontsize=14)  # Add x-axis label (adjust based on context)
ax.set_ylabel("Radial distribution funciton [O-O]", fontsize=14)  # Add y-axis label
# ax.set_title("", fontsize=16, pad=15)  # Add title
ax.legend(loc='best')  # Place legend in the best location

# Add gridlines (already included via Seaborn style, but can customize further)
ax.grid(True, linestyle='--', alpha=0.5)

# Adjust layout to prevent label clipping
plt.tight_layout()

# Display the plot
# plt.show()
fig.savefig('./figures/RDF-OO_500K.pdf', format='pdf', dpi=300, bbox_inches='tight')

# %% [markdown]
# Radial distribution function of H-H

# %%
dataHW = np.loadtxt("/home/linh/Numerical method 2/Part 2/NumericalII2025/NumericalII2022/MDTutorial/Exercises/Exc1/final_exam-nvt-500/time0.0005/displacement-HW.txt")

# %%
print(np.shape(dataOW))
print(np.shape(dataHW))
print(np.shape(BigHW[0]))
print(np.shape(BigOW[0]))
# Out:
# (400, 60)
# (400, 120)
# (40, 80, 3)
# (20, 80, 3)

# %%
for j in range(4):
    print((j+1)*80)
# Out:
# 80
# 160
# 240
# 320

# %%
dataHW = np.loadtxt("/home/linh/Numerical method 2/Part 2/NumericalII2025/NumericalII2022/MDTutorial/Exercises/Exc1/final_exam-nvt-500/time0.0005/displacement-HW.txt")


distanceHW = 25.2
# dis_r = []
BigHW = [[dataHW[(j+1)*80: (j+2)*80][:, i:i+3] for i in range(0, 120,3)] for j in range(4)]

# %%
distanceHW = 25.2
dis_rHW = [[] for _ in range(4)]

for int in range(len(BigHW)):
    for j in range(20):
        for k in range(j+1, (20)):
            for i in range(np.shape(BigHW[int])[1]):
                x = np.abs(BigHW[int][j][i][0] - BigHW[int][k][i][0])
                x = np.mod(x, distanceHW)

                if abs(x-distanceHW) < x:
                    x = abs(x-distanceHW)

                y = np.abs(BigHW[int][j][i][1] - BigHW[int][k][i][1])
                y = np.mod(y, distanceHW)

                if abs(y-distanceHW) < y:
                    y = abs(y-distanceHW)

                z = np.abs(BigHW[int][j][i][2] - BigHW[int][k][i][2])
                z = np.mod(z, distanceHW)

                if abs(z-distanceHW) < z:
                    z = abs(z-distanceHW)
            
                r = np.sqrt(x**2+y**2+z**2)
                
                # if r <= rcut:
                dis_rHW[int].append(r)

# %%
counts_dataHW = []


for i in range(4):
    bins_edgeHW = np.linspace(0, 25.196959335562/2*np.sqrt(3), 300)
    countsHW, _ = np.histogram(dis_rHW[i], bins=bins_edgeHW)
    
    normalzieHW= len(dis_rHW[i])

   
    disbin = bins_edgeHW[1] - bins_edgeHW[0]
    countsHW = countsHW /4/np.pi/(bins_edgeHW[:-1]+disbin/2)**2/(disbin)  
    
    
    counts_dataHW.append(countsHW/normalzieHW*25.196959335562**3)

    a = np.dot(counts_dataHW[i], bins_edgeHW[1:]**2)*4*np.pi*(bins_edgeHW[1] - bins_edgeHW[0]) / 25.196959335562**3
    print(a)
# Out:
# 1.010128353095186
# 1.009963707467209
# 1.0097135067485141
# 1.010083444764643

# %%
hw_hw = np.loadtxt("/home/linh/Numerical method 2/Part 2/NumericalII2025/NumericalII2022/MDTutorial/Exercises/Exc1/final_exam-nvt-500/time0.0005/hw-hw.txt")

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Set a modern style
plt.style.use('seaborn-v0_8-whitegrid')  # Clean white background with subtle gridlines
# plt.rcParams['font.family'] = 'Helvetica'  # Professional sans-serif font
plt.rcParams['axes.labelsize'] = 14  # Font size for labels
plt.rcParams['xtick.labelsize'] = 12  # Font size for ticks
plt.rcParams['ytick.labelsize'] = 12
plt.rcParams['legend.fontsize'] = 12

# Create the figure and axes
fig, ax = plt.subplots(figsize=(6, 4), dpi=150)  # Modern size and resolution

# Define data (assumed to be provided)
x = bins_edgeHW[1:]  # x-values (e.g., bin centers or edges)
y = np.average(counts_dataHW, axis=0)  # Mean values
yerr = np.std(counts_dataHW, axis=0)  # Standard deviation for error bars

# Plot error bars with modern styling
ax.errorbar(x, y, yerr=yerr, label="Estimates", 
            marker='o', markersize=5, markerfacecolor='green', markeredgecolor='black', 
            markeredgewidth=0.8
            , color='black', ecolor='black', 
            capsize=2, capthick=2, linewidth=1., alpha=0.9)

ax.plot(hw_hw[:,0], hw_hw[:,1], label="RDFDAT-DATA", color="purple")

ax.set_xlim(1.5, 7)
ax.set_ylim(-0.5, 10)

# Customize the plot
ax.set_xlabel(r"r ($\AA$)", fontsize=14)  # Add x-axis label (adjust based on context)
ax.set_ylabel("Radial distribution funciton [H-H]", fontsize=14)  # Add y-axis label
# ax.set_title("", fontsize=16, pad=15)  # Add title
ax.legend(loc='best')  # Place legend in the best location

# Add gridlines (already included via Seaborn style, but can customize further)
ax.grid(True, linestyle='--', alpha=0.5)

# Adjust layout to prevent label clipping
plt.tight_layout()

# Display the plot
# plt.show()
fig.savefig('./figures/RDF-HH_500K.pdf', format='pdf', dpi=300, bbox_inches='tight')

# %%
np.sum(np.where(np.array(dis_rHW)<0, np.array(dis_rHW), 0))
# Out:
# np.float64(0.0)

# %% [markdown]
# Radial distribution HW-OW

# %%
np.shape(BigOW[int])[1]
# Out:
# 80

# %%
print(np.shape(BigOW[0])[0])
# Out:
# 20

# %%
distanceOH = 25.2
dis_rOH = [[] for _ in range(4)]

for int in range(len(BigHW)):
    for j in range(np.shape(BigOW[0])[0]): # number of oxygen
        for k in range(np.shape(BigHW[0])[0]): # number of hydrogen
            for i in range(np.shape(BigHW[int])[1]):
                x = np.abs(BigOW[int][j][i][0] - BigHW[int][k][i][0])
                x = np.mod(x, distanceOH)

                if abs(x-distanceOH) < x:
                    x = abs(x-distanceOH)

                y = np.abs(BigOW[int][j][i][1] - BigHW[int][k][i][1])
                y = np.mod(y, distanceOH)

                if abs(y-distanceOH) < y:
                    y = abs(y-distanceOH)

                z = np.abs(BigOW[int][j][i][2] - BigHW[int][k][i][2])
                z = np.mod(z, distanceOH)

                if abs(z-distanceOH) < z:
                    z = abs(z-distanceOH)
            
                r = np.sqrt(x**2+y**2+z**2)
                
                # if r <= rcut:
                dis_rOH[int].append(r)

# %%
dis_rOH = np.array(dis_rOH)

# %%
# Modified

counts_dataOH = []
# bins_edgeOH = np.linspace(0.9497979995767515, 7, 100)
for i in range(4):
    # bins_edgeOH = np.linspace(min(dis_rOH[i]), max(dis_rOH[i]), 300)
    bins_edgeOH = np.linspace(0, 25.196959335562/2*np.sqrt(3), 300)
    countsOH, _ = np.histogram(dis_rOH[i], bins=bins_edgeOH)
    # normalzieOH = np.shape(dis_rOH[i])/(4/3*np.pi*np.max(dis_rOH[i])**3)
    
    normalzieOH = len(dis_rOH[i])


    # normalzieOH = 1
    disbin = bins_edgeOH[1] - bins_edgeOH[0]
    countsOH = countsOH /4/np.pi/(bins_edgeOH[:-1]+disbin/2)**2/(disbin)    # plt.plot

    # print(bins_edge)
    counts_dataOH.append(countsOH/normalzieOH*25.196959335562**3)

    a = np.dot(counts_dataOH[i], bins_edgeOH[1:]**2)*4*np.pi*(bins_edgeOH[1] - bins_edgeOH[0]) / 25.196959335562**3
    print(a)
# Out:
# 1.011405995423481
# 1.0112940406499427
# 1.0112757380541524
# 1.0112153714999585

# %%
ow_hw= np.loadtxt("/home/linh/Numerical method 2/Part 2/NumericalII2025/NumericalII2022/MDTutorial/Exercises/Exc1/final_exam-nvt-500/time0.0005/ow-hw.txt")

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Set a modern style
plt.style.use('seaborn-v0_8-whitegrid')  # Clean white background with subtle gridlines
# plt.rcParams['font.family'] = 'Helvetica'  # Professional sans-serif font
plt.rcParams['axes.labelsize'] = 14  # Font size for labels
plt.rcParams['xtick.labelsize'] = 12  # Font size for ticks
plt.rcParams['ytick.labelsize'] = 12
plt.rcParams['legend.fontsize'] = 12

# Create the figure and axes
fig, ax = plt.subplots(figsize=(6, 4), dpi=150)  # Modern size and resolution

# Define data (assumed to be provided)
x = bins_edgeOH[1:]  # x-values (e.g., bin centers or edges)
y = np.average(counts_dataOH, axis=0)  # Mean values
yerr = np.std(counts_dataOH, axis=0)  # Standard deviation for error bars

# Plot error bars with modern styling
ax.errorbar(x, y, yerr=yerr, label="Estimates", 
            marker='o', markersize=5, markerfacecolor='green', markeredgecolor='black', 
            markeredgewidth=0.8
            , color='black', ecolor='black', 
            capsize=2, capthick=2, linewidth=1., alpha=0.9)

ax.plot(ow_hw[:,0], ow_hw[:,1], label="RDFDAT-DATA", color="purple")

ax.set_xlim(0.9, 7)
ax.set_ylim(-0.5, 8)
# Customize the plot
ax.set_xlabel(r"r ($\AA$)", fontsize=14)  # Add x-axis label (adjust based on context)
ax.set_ylabel("Radial distribution funciton [O-H]", fontsize=14)  # Add y-axis label
# ax.set_title("", fontsize=16, pad=15)  # Add title
ax.legend(loc='best')  # Place legend in the best location

# Add gridlines (already included via Seaborn style, but can customize further)
ax.grid(True, linestyle='--', alpha=0.5)

# Adjust layout to prevent label clipping
plt.tight_layout()

# Display the plot
# plt.show()
fig.savefig('./figures/RDF-OH_500K.pdf', format='pdf', dpi=300, bbox_inches='tight')

# %% [markdown]
# Combine radial distribution data at 300K

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Set a modern style
plt.style.use('default')  # Use Seaborn's modern style for clean aesthetics "seaborn-v0_8"
# plt.rcParams['font.family'] = 'Helvetica'  # Modern sans-serif font
plt.rcParams['axes.linewidth'] = 1.2  # Slightly thicker axes for emphasis
plt.rcParams['xtick.labelsize'] = 12  # Consistent tick label size
plt.rcParams['ytick.labelsize'] = 12

# Define figure and axes with modern proportions
fig, ax = plt.subplots(3, 1, figsize=(4, 6), sharex=True, sharey=False, 
                       dpi=150)  # Adjusted size and higher DPI for clarity

# Define a modern color palette (if 'color' is not provided)
# Using 'viridis' colormap for a professional gradient
colors = sns.color_palette("rocket", n_colors=4)

# Plot data on each subplot
ax[0].errorbar(bins_edgeOW[1:], np.average(counts_dataOW, axis=0), yerr=np.std(counts_dataOW, axis=0), label="Estimates", 
            marker='o', markersize=5, markerfacecolor='green', markeredgecolor='black', 
            markeredgewidth=0.8
            , color='black', ecolor='black', 
            capsize=2, capthick=2, linewidth=1., alpha=0.9)

ax[0].plot(ow_ow[:,0], ow_ow[:,1], label="RDFDAT-DATA", color="purple")
# ax[0].set_xlim(2, 7)
ax[0].set_ylim(-0.5, 20)
ax[0].legend(loc='best')  # Place legend in the best location
ax[0].set_ylabel(r"$g_{\text{OO}}(r)$", fontsize=14)  # Add y-axis label


ax[1].errorbar(bins_edgeOH[1:], np.average(counts_dataOH, axis=0), yerr=np.std(counts_dataOH, axis=0), label="Estimates", 
            marker='o', markersize=5, markerfacecolor='green', markeredgecolor='black', 
            markeredgewidth=0.8
            , color='black', ecolor='black', 
            capsize=2, capthick=2, linewidth=1., alpha=0.9)

ax[1].plot(ow_hw[:,0], ow_hw[:,1], label="RDFDAT-DATA", color="purple")
ax[1].set_xlim(0.9, 7)
ax[1].set_ylim(-0.5, 10)
# Customize each subplot
for a in ax.flat:
    a.grid(True, linestyle='--', alpha=0.5)  # Subtle gridlines
    # a.legend(fontsize=12, loc='upper right')  # Legend in each subplot
    a.tick_params(axis='both', which='both', direction='in', length=5)  # Clean ticks

ax[1].set_ylabel(r"$g_{\text{OH}}(r)$", fontsize=14)  # Add y-axis label


ax[2].errorbar(bins_edgeHW[1:], np.average(counts_dataHW, axis=0), yerr=np.std(counts_dataHW, axis=0), label="Estimates", 
            marker='o', markersize=5, markerfacecolor='green', markeredgecolor='black', 
            markeredgewidth=0.8
            , color='black', ecolor='black', 
            capsize=2, capthick=2, linewidth=1., alpha=0.9)
ax[2].plot(hw_hw[:,0], hw_hw[:,1], label="RDFDAT-DATA", color="purple")
ax[2].set_xlim(1.5, 7)
ax[2].set_ylim(-0.5, 8)
ax[2].set_ylabel(r"$g_{\text{HH}}(r)$", fontsize=14)  # Add y-axis label



# fig.legend(loc='upper center' ,bbox_to_anchor=(0.5, 1.06),  ncol=4, fancybox=True, shadow=True, fontsize=10)
# Set axis limits (based on commented-out code)
# ax[0, 0].set_xlim(0, 50)
# ax[0, 0].set_ylim(-158.4, -158)

# Add labels and title
fig.supxlabel(r"r ($\AA$)", fontsize=14, y=0.05, x=0.5)  # Shared x-label below
# fig.supylabel("Potential energy (kJ/mol) \n at T=300K", fontsize=14, x=0.08, horizontalalignment='center')  # Shared y-label on left
# fig.suptitle("Potential energy (kJ/mol) at T=300K", fontsize=16, y=1.05)  # Title above

# Adjust layout to prevent overlap
plt.tight_layout()

# Display the plot
# plt.show()
fig.savefig('./figures/combine_RDF_500K.pdf', format='pdf', dpi=300, bbox_inches='tight')

# %%
np.shape(BigHW) # first axis: sub-interval, second axis: number of oxygen, third axis: number of steps, fourth axis: x,y,z.
# Out:
# (4, 40, 80, 3)

# %%
np.linalg.norm(BigHW[0][0][0] - BigHW[0][1][0])
# Out:
# np.float64(1.5073714633095585)

# %% [markdown]
# # Dipole fluctuation

# %%
dip_fluc = []

# %%
modBigOW = np.concatenate(BigOW, axis=1)
modBigHW = np.concatenate(BigHW, axis=1)

# %%
print(np.shape(modBigHW))
print(np.shape(modBigOW))
# Out:
# (40, 320, 3)
# (20, 320, 3)

# %%
# first axis: sub-interval, second axis: number of oxygen, third axis: number of steps, fourth axis: x,y,z.
dip_moment = []

two_nearest_hydrogen = [[], []]
distance = 25.196959335562*np.sqrt(3)
nearest_disance = [distance/2, distance/2] # choose large to find the nearest hydrogen
nearest_dis_index = [0, 0]
# dis = []

for j in range(np.size(modBigOW, axis=1)): # Time Step OW
# for j in range(10): # Time Step OW

    internal_dip = []
    for k in range(np.size(modBigOW, axis=0)): # Oxygen BigOW[i][k][j]
        int_dis = np.zeros(np.size(modBigHW, axis=0))
        for l in range(np.size(modBigHW, axis=0)):
            # print("------------------------" + str(l))
            # internal_dis = np.linalg.norm(modBigOW[k][j] - modBigHW[l][j])
            OH_dis = np.array(modBigOW[k][j] - modBigHW[l][j])

            OH_dis = OH_dis - np.where(OH_dis>0, OH_dis // (25.196959335562/2), OH_dis // (25.196959335562/2) +1) * (25.196959335562/2)
            # print(OH_dis)

            # internal_dis = np.mod(internal_dis, distance)
            # if np.abs(distance - internal_dis) < internal_dis:
            #     internal_dis = np.abs(distance - internal_dis)
            
            int_dis[l] = np.linalg.norm(OH_dis)

            # print("Internal dis", internal_dis)

            # if internal_dis < nearest_distance[np.mod(l,2)]:
            #     nearest_disance[np.mod(l,2)] = internal_dis
            #     nearest_dis_index[np.mod(l,2)] = l
            
        
        mod_int_dis = np.sort(int_dis)[:2]
        
        # print("dis: ", mod_int_dis)

        cut_off = 1.2

        if (mod_int_dis[0] >= cut_off) or (mod_int_dis[1] >= cut_off):
            break
        
        # print(mod_int_dis)

        nearest_dis_index[0] = np.where(int_dis==mod_int_dis[0])[0][0]
        nearest_dis_index[1] = np.where(int_dis==mod_int_dis[1])[0][0]
        # print("------------------------" + str(k))
        
        # print(mod_int_dis)

        # array1 = 2*modBigOW[k][j] - modBigHW[nearest_dis_index[0]][j] - modBigHW[nearest_dis_index[1]][j]
        array1 = modBigOW[k][j] - modBigHW[nearest_dis_index[0]][j]
        array2 = modBigOW[k][j] - modBigHW[nearest_dis_index[1]][j]
        
        array1 = array1 - np.where(array1>0, array1 // (25.196959335562/2), array1 // (25.196959335562/2) +1) * (25.196959335562/2)

        array2 = array2 - np.where(array2>0, array2 // (25.196959335562/2), array2 // (25.196959335562/2) +1) * (25.196959335562/2)

        # print(array1)
        # print(np.linalg.norm(array1))
        # # print(array2)
        # print(np.linalg.norm(array2))
        
        angle = np.arccos(np.dot(array1, array2) / (np.linalg.norm(array1) * np.linalg.norm(array2)))

        # print(angle)
        if angle > 120/180*np.pi:
            break

        big_array = array1 + array2
               
        # big_array = big_array - np.where(big_array>0, big_array // (25.196959335562/2), big_array // (25.196959335562/2) +1) * (25.196959335562/2)

        # Changing unit to debye unit
        transform_unit = 2.0232934131

        internal_dip.append(((big_array)*transform_unit).tolist())
    dip_moment.append(internal_dip)
    # print("-------------------------")

# %%
dip_moment_average = []
dip_moment_std = []
for j in range(len(dip_moment)):
    norm = 0
    std = 0 
    if len(dip_moment[j]) == 0:
        # print(j)
        continue
    
    # print(dip_moment[j]) 

    a = []
    for i in range(len(dip_moment[j])):
        a.append(np.linalg.norm(dip_moment[j][i]))
        # print(a)

    dip_moment_average.append(np.average(a))
    dip_moment_std.append(np.std(a))

    # print(stdp[-1])
    # print(dp[-1])

# %%
len(dip_moment_average)
# Out:
# 319

# %%
np.linspace(0, 0.0005*len(dip_moment_average), len(dip_moment_average))
# Out:
# 319

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Set a modern style
plt.style.use('seaborn-v0_8-whitegrid')  # Clean white background with subtle gridlines
# plt.rcParams['font.family'] = 'Helvetica'  # Professional sans-serif font
plt.rcParams['axes.labelsize'] = 14  # Font size for labels
plt.rcParams['xtick.labelsize'] = 12  # Font size for ticks
plt.rcParams['ytick.labelsize'] = 12
plt.rcParams['legend.fontsize'] = 12

# Create the figure and axes
fig, ax = plt.subplots(figsize=(6, 4), dpi=150)  # Modern size and resolution


ax.errorbar(np.linspace(0.0005*80*100, 0.0005*len(dip_moment_average)*100 +0.0005*80*100, len(dip_moment_average)), dip_moment_average, yerr=dip_moment_std, label="Estimates", 
            marker='o', markersize=6, markerfacecolor='green', markeredgecolor='black', 
            markeredgewidth=0.8
            , color='black', ecolor='black', 
            capsize=2, capthick=2, linewidth=1., alpha=0.9)

ax.set_xlabel(r"Time (ps)", fontsize=14)  # Add x-axis label (adjust based on context)
ax.set_ylabel("Dipole moment [D]", fontsize=14)  # Add y-axis label

ax.grid(True, linestyle='--', alpha=0.5)

# Adjust layout to prevent label clipping
plt.tight_layout()

# Display the plot
# plt.show()
fig.savefig('./figures/Dipole_moment_500K.pdf', format='pdf', dpi=300, bbox_inches='tight')

# %%
print(np.average(dip_moment_average))
print(np.average(dip_moment_std))
# Out:
# 2.3436450501898505
# 0.023752138974773882

# %%
total_data_dipole_moment = []
for j in range(len(dip_moment)):
    norm = 0
    std = 0 
    if len(dip_moment[j]) == 0:
        # print(j)
        continue
    
    # print(dip_moment[j]) 
    for i in range(len(dip_moment[j])):
        total_data_dipole_moment.append(np.linalg.norm(dip_moment[j][i]))
        # print(a)

    

    # print(stdp[-1])
    # print(dp[-1])

# %%
print(np.average(total_data_dipole_moment))
print(np.std(total_data_dipole_moment))
# Out:
# 2.347190550170434
# 0.0938119523280706

# %% [markdown]
# # Diffusion constant

# %%
np.shape(dataHW)
# Out:
# (4000, 120)

# %%
400/800
# Out:
# 0.5

# %%
modBigOW = [[dataOW[(j+1)*800: (j+2)*800][:, i:i+3] for i in range(0, 120,3)] for j in range(4)]

# %%
np.shape(modBigOW)
# Out:
# (20, 320, 3)

# %%
displacement_OW = [[] for _ in range(4)]
print(displacement_OW)
# Out:
# [[], [], [], []]

# %%
np.shape(modBigOW)
# Out:
# (20, 320, 3)

# %%
modBigOW[0][1]
# Out:
# array([ 11.251  , -12.423  ,   0.72748])

# %%
displacement_OW = []

for i in range(1, np.size(modBigOW, axis=1)): # Time
    int_displace = []
    for j in range(np.size(modBigOW, axis=0)): # Oxygen
        int_displace.append(np.linalg.norm(modBigOW[j][i] - modBigOW[j][0])**2)
    displacement_OW.append(int_displace)

# %%
displacement_OW
# Out:
# [[np.float64(0.15456404810000007),
#   np.float64(0.10481543999999936),
#   np.float64(0.10797124000000037),
#   np.float64(0.19048915999999974),
#   np.float64(0.34234600999999926),
#   np.float64(0.3415341761),
#   np.float64(0.17968116999999986),
#   np.float64(0.6590152103999998),
#   np.float64(0.2632584499999997),
#   np.float64(0.5427317600000001),
#   np.float64(0.015223250000000008),
#   np.float64(0.0567208099999998),
#   np.float64(0.037974250000000154),
#   np.float64(0.3490692500000004),
#   np.float64(0.11052693000000018),
#   np.float64(0.0474884599999999),
#   np.float64(0.22656285689999994),
#   np.float64(0.24779174),
#   np.float64(0.20528019000000028),
#   np.float64(627.8997935000001)],
#  [np.float64(0.9727505081000009),
#   np.float64(0.4378800899999996),
#   np.float64(0.5275298200000005),
#   np.float64(1.140061922499999),
#   np.float64(1.0367613999999992),
#   np.float64(1.4667585138559995),
#   np.float64(0.7763757400000023),
# ...

# %%
np.linspace(0.0005*80*100, 0.0005*len(displacement_HW)*100 +0.0005*80*100, len(displacement_HW))

# %%
len(np.average(displacement_HW, axis=0))
# Out:
# 40

# %%
modBigOW
# Out:
# array([[[ 10.905  , -12.452  ,   0.91189],
#         [ 11.251  , -12.423  ,   0.72748],
#         [ 11.667  , -12.489  ,   0.2868 ],
#         ...,
#         [ -2.0474 ,   6.1726 ,  10.36   ],
#         [ -1.9356 ,   6.3925 ,  10.476  ],
#         [ -1.8093 ,   6.5199 ,  10.582  ]],
#
#        [[ 10.664  , -11.022  ,   3.4703 ],
#         [ 10.764  , -11.293  ,   3.3241 ],
#         [ 10.926  , -11.456  ,   3.045  ],
#         ...,
#         [ -0.91163,   4.1832 ,  12.385  ],
#         [ -0.78381,   4.1996 ,  12.421  ],
#         [ -0.56316,   4.2115 ,  12.442  ]],
#
#        [[ -6.9149 ,   7.2678 ,  -2.1126 ],
#         [ -6.6533 ,   7.122  ,  -1.9774 ],
#         [ -6.3038 ,   6.9423 ,  -1.8932 ],
#         ...,
#         [  2.241  ,   5.3506 ,   3.7106 ],
#         [  2.2306 ,   5.5951 ,   3.7873 ],
#         [  2.1508 ,   5.7897 ,   4.1107 ]],
#
#        ...,
#
#        [[ -4.0003 ,  -2.1011 ,  -5.3217 ],
#         [ -4.4816 ,  -2.2277 ,  -5.311  ],
# ...

# %%
displacement_OW
# Out:
# [[np.float64(0.15456404810000007),
#   np.float64(0.10481543999999936),
#   np.float64(0.10797124000000037),
#   np.float64(0.19048915999999974),
#   np.float64(0.34234600999999926),
#   np.float64(0.3415341761),
#   np.float64(0.17968116999999986),
#   np.float64(0.6590152103999998),
#   np.float64(0.2632584499999997),
#   np.float64(0.5427317600000001),
#   np.float64(0.015223250000000008),
#   np.float64(0.0567208099999998),
#   np.float64(0.037974250000000154),
#   np.float64(0.3490692500000004),
#   np.float64(0.11052693000000018),
#   np.float64(0.0474884599999999),
#   np.float64(0.22656285689999994),
#   np.float64(0.24779174),
#   np.float64(0.20528019000000028),
#   np.float64(627.8997935000001)],
#  [np.float64(0.9727505081000009),
#   np.float64(0.4378800899999996),
#   np.float64(0.5275298200000005),
#   np.float64(1.140061922499999),
#   np.float64(1.0367613999999992),
#   np.float64(1.4667585138559995),
#   np.float64(0.7763757400000023),
# ...

# %%
# Out:
# array([1.54564048e-01, 9.72750508e-01, 6.21148742e+02, 6.10618599e+02,
#        6.03552422e+02, 1.14998720e+03, 1.14877117e+03, 1.15353311e+03,
#        1.16008700e+03, 5.31195547e+02, 5.25364473e+02, 5.19457246e+02,
#        5.13744380e+02, 5.04505838e+02, 4.97027028e+02, 4.92686416e+02,
#        4.85500795e+02, 4.78362658e+02, 4.70912490e+02, 4.58466665e+02,
#        4.49690910e+02, 4.44654241e+02, 4.46352893e+02, 4.55626787e+02,
#        4.62713349e+02, 4.70834600e+02, 4.72701077e+02, 4.72427733e+02,
#        4.78579694e+02, 4.80737281e+02, 4.81497234e+02, 4.77892984e+02,
#        4.74360315e+02, 4.67580934e+02, 4.65885137e+02, 4.65768426e+02,
#        4.65529049e+02, 4.58211111e+02, 4.57234042e+02, 4.63532344e+02,
#        4.61099526e+02, 4.52480081e+02, 4.47001988e+02, 4.41856433e+02,
#        4.48177095e+02, 4.55223953e+02, 4.51080830e+02, 4.39384677e+02,
#        4.20984060e+02, 4.13660009e+02, 4.03901207e+02, 1.01456391e+03,
# ...

# %%
plt.plot(np.linspace(0, 0.0005*np.size(displacement_OW, axis=)*100*10**-12, np.size(displacement_OW, axis=)), np.array(displacement_OW).T[0]*10**-10, label="orgin")

# a = np.linspace(0, 0.0005*len(displacement_HW)*100*10**-12, len(displacement_HW))
# plt.plot(a, (2*a*10**-10)**1/2, label="compare")
# plt.plot(a, (2*a*10**-10)**1/2, label="compare")

# plt.yscale("log")
# plt.xscale("log")
# plt.legend()

# %%
plt.plot(np.linspace(0, 0.0005*len(modBigOW)*100*10**-12, len(modBigOW)), np.average(modBigOW, axis=1)*10**-10, label="orgin")

# a = np.linspace(0, 0.0005*len(displacement_HW)*100*10**-12, len(displacement_HW))
# plt.plot(a, (2*a*10**-10)**1/2, label="compare")
# plt.plot(a, (2*a*10**-10)**1/2, label="compare")

# plt.yscale("log")
# plt.xscale("log")
# plt.legend()

# %%
plt.errorbar(np.linspace(0, 0.0005*len(displacement_HW)*100*10**-12, len(displacement_HW)), np.average(displacement_HW, axis=1), yerr=np.std(displacement_HW, axis=1), label="Estimates", 
            marker='o', markersize=6, markerfacecolor='green', markeredgecolor='black', 
            markeredgewidth=0.8
            , color='black', ecolor='black', 
            capsize=2, capthick=2, linewidth=1., alpha=0.9)

plt.yscale("log")
plt.xscale("log")

# %%
plt.errorbar(np.linspace(0, len(displacement_HW), len(displacement_HW)), np.average(displacement_HW, axis=1), yerr=np.std(displacement_HW, axis=1), label="Estimates", 
            marker='o', markersize=6, markerfacecolor='green', markeredgecolor='black', 
            markeredgewidth=0.8
            , color='black', ecolor='black', 
            capsize=2, capthick=2, linewidth=1., alpha=0.9)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Set a modern style
plt.style.use('seaborn-v0_8-whitegrid')  # Clean white background with subtle gridlines
# plt.rcParams['font.family'] = 'Helvetica'  # Professional sans-serif font
plt.rcParams['axes.labelsize'] = 14  # Font size for labels
plt.rcParams['xtick.labelsize'] = 12  # Font size for ticks
plt.rcParams['ytick.labelsize'] = 12
plt.rcParams['legend.fontsize'] = 12

# Create the figure and axes
fig, ax = plt.subplots(figsize=(6, 4), dpi=150)  # Modern size and resolution


ax.errorbar(np.linspace(0.0005*80*100, 0.0005*len(dip_moment_average)*100 +0.0005*80*100, len(dip_moment_average)), dip_moment_average, yerr=dip_moment_std, label="Estimates", 
            marker='o', markersize=6, markerfacecolor='green', markeredgecolor='black', 
            markeredgewidth=0.8
            , color='black', ecolor='black', 
            capsize=2, capthick=2, linewidth=1., alpha=0.9)

ax.set_xlabel(r"Time (ps)", fontsize=14)  # Add x-axis label (adjust based on context)
ax.set_ylabel("Dipole moment [D]", fontsize=14)  # Add y-axis label

ax.grid(True, linestyle='--', alpha=0.5)

# Adjust layout to prevent label clipping
plt.tight_layout()

# Display the plot
# plt.show()
# fig.savefig('./figures/Dipole_moment_300K.pdf', format='pdf', dpi=300, bbox_inches='tight')
